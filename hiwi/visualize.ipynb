# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import numpy
from pruneshift.datamodules import ShiftDataModule as dm
from torch.utils.data import DataLoader

from pruneshift.networks import create_network

from torchvision.datasets import ImageFolder
from torchvision import transforms

import matplotlib.pyplot as plt
from PIL import Image

path_test="/misc/scratchSSD2/datasets/ILSVRC2012-100/val"
path_brightness_1="/misc/scratchSSD2/datasets/ILSVRC2012-100/corrupted/brightness/1"
path_brightness_3="/misc/scratchSSD2/datasets/ILSVRC2012-100/corrupted/brightness/3"
path_brightness_5="/misc/scratchSSD2/datasets/ILSVRC2012-100/corrupted/brightness/5"
path_renditions="/misc/scratchSSD2/datasets/ILSVRC2012-100/renditions"

# %%
data_transform = transforms.Compose([transforms.Resize(256),
        transforms.CenterCrop(224),        
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])
datasets = ImageFolder(root=path_test, transform=data_transform)
dataset_loader = DataLoader(datasets, batch_size=32, shuffle=False, num_workers=4, drop_last=False, pin_memory=False)

# %%
datasets_test = ImageFolder(root=path_test)

dataset_loader = DataLoader(datasets, batch_size=32, shuffle=False, num_workers=4, drop_last=False, pin_memory=False)

# %%
datasets = ImageFolder(root=path_test)
image, target = datasets[-1]
#im = Image(image)
plt.imshow(image)

# %%
datasets_test = ImageFolder(root=path_brightness_1)
image, target = datasets_test[-1]
plt.imshow(image)

# %%
datasets_test = ImageFolder(root=path_brightness_3)
image, target = datasets_test[-1]
plt.imshow(image)

# %%
datasets_test = ImageFolder(root=path_brightness_5)
image, target = datasets_test[-1]
plt.imshow(image)

# %%
datasets_test = ImageFolder(root=path_renditions)
image, target = datasets_test[-1]
plt.imshow(image)

# %%
image, target = datasets[0]

fig, axes = plt.subplots(1, 3, figsize=(8, 8))
for lvl, row in enumerate(axes):
    for idx, ax in enumerate(row):
        imgs, y = datasets[0]
        img = (255 * imgs[0]).permute([1, 2, 0]).to(torch.uint8).numpy()
        ax.imshow(Image.fromarray(img))
        ax.axis('off')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3815694/3265356440.py in <module>
#       3 fig, axes = plt.subplots(1, 3, figsize=(8, 8))
#       4 for lvl, row in enumerate(axes):
# ----> 5     for idx, ax in enumerate(row):
#       6         imgs, y = datasets[0]
#       7         img = (255 * imgs[0]).permute([1, 2, 0]).to(torch.uint8).numpy()
#
# TypeError: 'AxesSubplot' object is not iterable

# %%
imgs, y = datasets[0]
#img = (255 * imgs).permute([1, 2, 0]).to(torch.uint8).numpy()
Image(imgs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3815694/441436655.py in <module>
#       1 imgs, y = datasets[0]
#       2 #img = (255 * imgs).permute([1, 2, 0]).to(torch.uint8).numpy()
# ----> 3 Image(imgs)
#
# TypeError: 'module' object is not callable

# %%
from utils import collect, to_percentage
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from math import pi

import numpy as np


hydra_path = Path("/work/dlclarge2/hoffmaja-pruneshift/experiments/img100/workshop/subnet_final/tune/")
weight_path = Path("/work/dlclarge2/hoffmaja-pruneshift/experiments/img100/workshop/subnet_final/global_weight/")
baseline_path = Path("/work/dlclarge2/hoffmaja-pruneshift/experiments/img100/workshop/baselines")
errors = ["ImageNet100 Error", "ImageNet100-C Error", "ImageNet100-R Error"]

# %%
df_amda = collect("/work/dlclarge2/hoffmaja-pruneshift/experiments/img100/workshop/baselines/1times_amda/")
df_kd_amda = collect("/work/dlclarge2/hoffmaja-pruneshift/experiments/img100/kd/kd_amda/",
                     "/work/dlclarge2/hoffmaja-pruneshift/experiments/img100/workshop/amda_distillation/").query("Teacher == 'AMDA Resnet50'")
pd.concat([df_amda, df_kd_amda]).to_csv("kd_amda.csv")

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/")

# %%
df_mobile_hydra_amda = collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mobilenet_v2/hydra_amda/").query("not `Hydra Loss`.isnull()")
df_mobile_hydra_kd_amda = collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mobilenet_v2/hydra_kd_amda/").query("not `Hydra Loss`.isnull()")
df_mobile_layer_weight = collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mobilenet_v2/layer_weight_amda/")

df_mobile = pd.concat([df_mobile_hydra_amda, df_mobile_hydra_kd_amda, df_mobile_layer_weight])
df_mobile.to_csv("mobile_hydra.csv")

# %%
df_mnas_hydra_amda = collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mnasnet/hydra_amda/").query("not `Hydra Loss`.isnull()")
df_mnas_hydra_kd_amda = collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mnasnet/hydra_kd_amda/").query("not `Hydra Loss`.isnull()")
df_mnas_layer_weight = collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mnasnet/layer_weights_amda/")
df_mnas = pd.concat([df_mobile_hydra_amda, df_mobile_hydra_kd_amda, df_mobile_layer_weight])
df_mnas.to_csv("mnas_hydra.csv")

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/amda_resnet/mask_selection/finetuning")["Path"].to_numpy()
# Out:
# array(['/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/amda_resnet/mask_selection/finetuning/3',
#        '/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/amda_resnet/mask_selection/finetuning/0',
#        '/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/amda_resnet/mask_selection/finetuning/2',
#        '/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/amda_resnet/mask_selection/finetuning/1'],
#       dtype=object)

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mobilenet_v2/hydra_amda/").query("not `Hydra Loss`.isnull()")
# Out:
#     Amda  Augmix  DeepAugment  Epochs Hydra Amda    Hydra Loss  \
# 90  True    True         True      30       True  StandardLoss
# 90  True    True         True      30       True  StandardLoss
# 90  True    True         True      30       True  StandardLoss
# 90  True    True         True      30       True  StandardLoss
#
#     ImageNet100 Error  ImageNet100-C Error  ImageNet100-R Error          Loss  \
# 90             0.2272             0.424912             0.622995  StandardLoss
# 90             0.3818             0.596336             0.731570  StandardLoss
# 90             0.1430             0.328432             0.566477  StandardLoss
# 90             0.5906             0.766909             0.833420  StandardLoss
#
#          Network                                               Path  \
# 90  mobilenet_v2  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...
# 90  mobilenet_v2  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mobilenet_v2/hydra_kd_amda/").query("not `Hydra Loss`.isnull()")
# Out:
#     Amda  Augmix  DeepAugment  Epochs Hydra Amda        Hydra Loss  \
# 90  True    True         True      30       True  KnowledgeDistill
# 90  True    True         True      30       True  KnowledgeDistill
# 90  True    True         True      30       True  KnowledgeDistill
# 90  True    True         True      30       True  KnowledgeDistill
#
#     ImageNet100 Error  ImageNet100-C Error  ImageNet100-R Error  \
# 90             0.1934             0.412872             0.614718
# 90             0.2874             0.508563             0.691024
# 90             0.1220             0.327155             0.550310
# 90             0.9900             0.990000             0.989977
#
#                 Loss       Network  \
# 90  KnowledgeDistill  mobilenet_v2
# 90  KnowledgeDistill  mobilenet_v2
# 90  KnowledgeDistill  mobilenet_v2
# 90  KnowledgeDistill  mobilenet_v2
#
#                                                  Path  Prune Ratio  Scaling  \
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mnasnet/layer_weights_amda/")
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90  True    True         True      30             0.2030             0.395488
# 90  True    True         True      30             0.1400             0.316723
# 90  True    True         True      30             0.2640             0.458651
# 90  True    True         True      30             0.4262             0.590677
#
#     ImageNet100-R Error          Loss     Network  \
# 90             0.611032  StandardLoss  mnasnet1_0
# 90             0.573461  StandardLoss  mnasnet1_0
# 90             0.654488  StandardLoss  mnasnet1_0
# 90             0.782462  StandardLoss  mnasnet1_0
#
#                                                  Path Prune Amount  \
# 90  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...         None
# 90  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...         None
# 90  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...         None
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mnasnet/hydra_kd_amda/").query("`Hydra Loss`.isnull()")
# Out:
#     Amda  Augmix  DeepAugment  Epochs Hydra Amda Hydra Loss  \
# 90  True    True         True      30        NaN        NaN
# 90  True    True         True      30        NaN        NaN
# 90  True    True         True      30        NaN        NaN
# 90  True    True         True      30        NaN        NaN
#
#     ImageNet100 Error  ImageNet100-C Error  ImageNet100-R Error  \
# 90             0.3068             0.571176             0.683717
# 90             0.5980             0.765277             0.764097
# 90             0.1556             0.362333             0.575854
# 90             0.6754             0.779725             0.847517
#
#                 Loss     Network  \
# 90  KnowledgeDistill  mnasnet1_0
# 90  KnowledgeDistill  mnasnet1_0
# 90  KnowledgeDistill  mnasnet1_0
# 90  KnowledgeDistill  mnasnet1_0
#
#                                                  Path  Prune Ratio  Scaling  \
# 90  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...          NaN        1
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mnasnet/hydra_amda/").query("`Hydra Loss`.isnull()")
# Out:
#     Amda  Augmix  DeepAugment  Epochs Hydra Amda Hydra Loss  \
# 90  True    True         True      30        NaN        NaN
# 90  True    True         True      30        NaN        NaN
# 90  True    True         True      30        NaN        NaN
# 90  True    True         True      30        NaN        NaN
#
#     ImageNet100 Error  ImageNet100-C Error  ImageNet100-R Error          Loss  \
# 90             0.4858             0.665485             0.755691  StandardLoss
# 90             0.1746             0.401285             0.593249  StandardLoss
# 90             0.6472             0.772837             0.868081  StandardLoss
# 90             0.8862             0.942443             0.911084  StandardLoss
#
#        Network                                               Path  \
# 90  mnasnet1_0  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...
# 90  mnasnet1_0  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...
# 90  mnasnet1_0  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/experiments/img100/kd/")
# Out:
#       Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  \
# 270  False   False        False      90             0.1020
# 90    True    True         True      30             0.0966
# 270  False   False        False      90             0.1074
# 270  False   False        False      90             0.1066
# 270  False   False        False      90             0.1004
# 90    True    True         True      30             0.1200
# 90    True    True         True      30             0.1056
# 270  False   False        False      90             0.0986
# 90    True    True         True      30             0.1104
# 270  False   False        False      90             0.1004
# 90    True    True         True      30             0.1208
# 270  False   False        False      90             0.0958
# 270  False   False        False      90             0.0986
# 270  False   False        False      90             0.1014
# 270  False   False        False      90             0.0990
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/global_weight")
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90  True    True         True      30             0.1394             0.323827
# 90  True    True         True      30             0.2310             0.440480
# 90  True    True         True      30             0.1704             0.366968
# 90  True    True         True      30             0.3326             0.558880
#
#     ImageNet100-R Error          Loss   Network  \
# 90             0.571198  StandardLoss  resnet18
# 90             0.652613  StandardLoss  resnet18
# 90             0.599198  StandardLoss  resnet18
# 90             0.735450  StandardLoss  resnet18
#
#                                                  Path Prune Amount  \
# 90  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...         None
# 90  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...         None
# 90  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...         None
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/experiments/img100/workshop/amda_distillation/")
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90  True    True         True      30             0.1152             0.299720
# 3   True    True         True      30                NaN                  NaN
# 90  True    True         True      30             0.1136             0.292848
#
#     ImageNet100-R Error              Loss       Network  \
# 90             0.532527  KnowledgeDistill  mobilenet_v2
# 3                   NaN  KnowledgeDistill      resnet18
# 90             0.531557  KnowledgeDistill    mnasnet1_0
#
#                                                  Path  Scaling        Teacher
# 90  /work/dlclarge2/hoffmaja-pruneshift/experiment...        1  AMDA Resnet50
# 3   /work/dlclarge2/hoffmaja-pruneshift/experiment...        1  AMDA Resnet50
# 90  /work/dlclarge2/hoffmaja-pruneshift/experiment...        1  AMDA Resnet50

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/experiments/img100/workshop/baselines/1times_amda/")
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90  True    True         True      30             0.1308             0.303920
# 90  True    True         True      30             0.1298             0.280128
# 90  True    True         True      30             0.1316             0.304213
#
#     ImageNet100-R Error          Loss       Network  \
# 90             0.559881  StandardLoss    mnasnet1_0
# 90             0.535631  StandardLoss      resnet18
# 90             0.563502  StandardLoss  mobilenet_v2
#
#                                                  Path  Scaling
# 90  /work/dlclarge2/hoffmaja-pruneshift/experiment...        1
# 90  /work/dlclarge2/hoffmaja-pruneshift/experiment...        1
# 90  /work/dlclarge2/hoffmaja-pruneshift/experiment...        1

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/experiments/img100/kd/kd_amda/")
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90  True    True         True      30             0.1056             0.260021
# 90  True    True         True      30             0.1002             0.295056
# 90  True    True         True      30             0.0966             0.317541
#
#     ImageNet100-R Error              Loss   Network  \
# 90             0.500129  KnowledgeDistill  resnet18
# 90             0.517783  KnowledgeDistill  resnet18
# 90             0.559816  KnowledgeDistill  resnet18
#
#                                                  Path  Scaling        Teacher
# 90  /work/dlclarge2/hoffmaja-pruneshift/experiment...        1  AMDA Resnet50
# 90  /work/dlclarge2/hoffmaja-pruneshift/experiment...        1  SWSL Resnet50
# 90  /work/dlclarge2/hoffmaja-pruneshift/experiment...        1   STD Resnet50

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs/l1_channel/resnet50_amda_to_resnet18_1.0/")
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90  True    True         True      30             0.1066             0.268296
#
#     ImageNet100-R Error              Loss   Network  \
# 90             0.497478  KnowledgeDistill  resnet18
#
#                                                  Path  Prune Amount  \
# 90  /work/dlclarge2/hoffmaja-pruneshift/shashank_r...           0.5
#
#    Prune Method Prune Ratio  Scaling        Teacher
# 90    L¹ Filter        None     1.45  AMDA Resnet50

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/amda_resnet/pruning_amda").sort_values(by=["Prune Method", "Prune Amount"])
# Out:
#      Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  \
# 180  True    True         True      60             0.0994
# 180  True    True         True      60             0.0992
# 180  True    True         True      60             0.0972
# 180  True    True         True      60             0.0970
# 180  True    True         True      60             0.1052
# 180  True    True         True      60             0.1500
# 180  True    True         True      60             0.1006
# 180  True    True         True      60             0.1018
# 180  True    True         True      60             0.1138
#
#      ImageNet100-C Error  ImageNet100-R Error          Loss   Network  \
# 180             0.230016             0.499806  StandardLoss  resnet18
# 180             0.232133             0.502716  StandardLoss  resnet18
# 180             0.233741             0.505755  StandardLoss  resnet18
# 180             0.231293             0.493921  StandardLoss  resnet18
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/amda_resnet/kd_pruning_amda/").sort_values(by=["Prune Method", "Prune Amount"])
# Out:
#      Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  \
# 180  True    True         True      60             0.0770
# 180  True    True         True      60             0.0794
# 180  True    True         True      60             0.0778
# 180  True    True         True      60             0.0792
# 180  True    True         True      60             0.0904
# 180  True    True         True      60             0.1304
#
#      ImageNet100-C Error  ImageNet100-R Error              Loss   Network  \
# 180             0.222125             0.461200  KnowledgeDistill  resnet18
# 180             0.224235             0.464757  KnowledgeDistill  resnet18
# 180             0.233691             0.474521  KnowledgeDistill  resnet18
# 180             0.226899             0.466244  KnowledgeDistill  resnet18
# 180             0.250139             0.477108  KnowledgeDistill  resnet18
# 180             0.321819             0.530264  KnowledgeDistill  resnet18
#
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mnasnet/pruning_amda/").sort_values(by=["Prune Method", "Prune Amount"])
# Out:
#      Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  \
# 180  True    True         True      60             0.1076
# 180  True    True         True      60             0.1042
# 180  True    True         True      60             0.1106
# 96   True    True         True      60                NaN
# 180  True    True         True      60             0.1280
# 180  True    True         True      60             0.3258
# 180  True    True         True      60             0.1178
# 180  True    True         True      60             0.1514
# 180  True    True         True      60             0.2310
#
#      ImageNet100-C Error  ImageNet100-R Error          Loss  Network  \
# 180             0.277917             0.528777  StandardLoss  mnasnet
# 180             0.276339             0.533432  StandardLoss  mnasnet
# 180             0.285592             0.535502  StandardLoss  mnasnet
# 96                   NaN                  NaN  StandardLoss  mnasnet
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mnasnet/kd_pruning_amda/").sort_values(by=["Prune Method", "Prune Amount"])
# Out:
#      Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  \
# 180  True    True         True      60             0.0918
# 180  True    True         True      60             0.0982
# 180  True    True         True      60             0.1048
# 180  True    True         True      60             0.0986
# 180  True    True         True      60             0.1148
# 180  True    True         True      60             0.2986
#
#      ImageNet100-C Error  ImageNet100-R Error              Loss  Network  \
# 180             0.275909             0.507437  KnowledgeDistill  mnasnet
# 180             0.275747             0.509635  KnowledgeDistill  mnasnet
# 180             0.283856             0.516555  KnowledgeDistill  mnasnet
# 180             0.282771             0.510670  KnowledgeDistill  mnasnet
# 180             0.302469             0.534532  KnowledgeDistill  mnasnet
# 180             0.521504             0.637028  KnowledgeDistill  mnasnet
#
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mobilenet_v2/pruned_amda/").sort_values(by=["Prune Method", "Prune Amount"])
# Out:
#      Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  \
# 180  True    True         True      60             0.1062
# 180  True    True         True      60             0.1124
# 180  True    True         True      60             0.1176
# 180  True    True         True      60             0.1104
# 180  True    True         True      60             0.1346
# 180  True    True         True      60             0.2622
# 180  True    True         True      60             0.1170
# 180  True    True         True      60             0.1554
# 180  True    True         True      60             0.2426
#
#      ImageNet100-C Error  ImageNet100-R Error          Loss       Network  \
# 180             0.273360             0.533432  StandardLoss  mobilenet_v2
# 180             0.280373             0.539317  StandardLoss  mobilenet_v2
# 180             0.289693             0.548952  StandardLoss  mobilenet_v2
# 180             0.279203             0.535049  StandardLoss  mobilenet_v2
# ...

# %%
collect("/work/dlclarge2/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mobilenet_v2/kd_pruned_amda").sort_values(by=["Prune Method", "Prune Amount"])
# Out:
#      Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  \
# 180  True    True         True      60             0.0952
# 180  True    True         True      60             0.0966
# 180  True    True         True      60             0.1036
# 180  True    True         True      60             0.0992
# 180  True    True         True      60             0.1132
# 180  True    True         True      60             0.2258
#
#      ImageNet100-C Error  ImageNet100-R Error              Loss       Network  \
# 180             0.270760             0.504333  KnowledgeDistill  mobilenet_v2
# 180             0.275611             0.505561  KnowledgeDistill  mobilenet_v2
# 180             0.291056             0.521599  KnowledgeDistill  mobilenet_v2
# 180             0.278403             0.502393  KnowledgeDistill  mobilenet_v2
# 180             0.301563             0.522375  KnowledgeDistill  mobilenet_v2
# 180             0.446755             0.638321  KnowledgeDistill  mobilenet_v2
#
# ...

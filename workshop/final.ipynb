# %%
from utils import collect, add_info
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from math import pi
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import numpy as np

# %%
amda_ensemble_pruned_together=collect(Path("/work/dlclarge1/agnihotr-ensemble/train_emsemble/imagenet100/amda/together/")).sort_values(by="Prune Amount")
amda_ensemble_pruned_together["Model Size"]=[30.287340, 25.266156, 16.824300, 10.098924, 3.348972]

# %%
standard_ensemble_pruned_together=collect(Path("/work/dlclarge1/agnihotr-ensemble/train_emsemble/imagenet100/standard/together/")).sort_values(by="Prune Amount")
standard_ensemble_pruned_together["Model Size"]=[30.287340, 25.266156, 16.824300, 10.098924, 3.348972]

# %%
standard_ensemble_pruned_together
# Out:
#       Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  \
# 270  False   False        False      90           9.960002
# 270  False   False        False      90          10.380000
# 270  False   False        False      90          11.379999
# 270  False   False        False      90          12.800002
# 270  False   False        False      90          23.979998
#
#      ImageNet100-C Error  ImageNet100-R Error  LearningRate          Loss  \
# 270            48.253065            66.334713           0.1  StandardLoss
# 270            48.721868            65.836781           0.1  StandardLoss
# 270            50.373864            66.593379           0.1  StandardLoss
# 270            53.721595            67.776772           0.1  StandardLoss
# 270            67.702663            75.523797           0.1  StandardLoss
#
#       Network  ... Prune Ratio  Scaling WeightDecay  ensemble  kd_T  \
# 270  resnet18  ...    1.111111        1      0.0002      True  None
# ...

# %%
amda_ensemble_pruned_together
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90  True    True         True      30          11.199999            24.847198
# 90  True    True         True      30          11.400002            25.659734
# 90  True    True         True      30          12.680000            27.543998
# 90  True    True         True      30          15.480000            32.286668
# 90  True    True         True      30          30.919999            51.896274
#
#     ImageNet100-R Error  LearningRate          Loss   Network  ...  \
# 90            51.519659           0.1  StandardLoss  resnet18  ...
# 90            52.250388           0.1  StandardLoss  resnet18  ...
# 90            53.265649           0.1  StandardLoss  resnet18  ...
# 90            55.942836           0.1  StandardLoss  resnet18  ...
# 90            69.432229           0.1  StandardLoss  resnet18  ...
#
#    Prune Ratio  Scaling WeightDecay  ensemble  kd_T  kd_mixture  \
# ...

# %%
amda_scaled=collect(Path("/work/dlclarge1/agnihotr-ensemble/scaled_resnet18/imagenet100/amda_1.73")).sort_values(by="Path")
standard_scaled=collect(Path("/work/dlclarge1/agnihotr-ensemble/scaled_resnet18/imagenet100/standard_1.73")).sort_values(by="Path")
pruned_scaled=collect(Path("/work/dlclarge1/agnihotr-ensemble/scaled_resnet18/imagenet100/pruned")).sort_values(by="Path")

# %%
amda_scaled
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90  True    True         True      30          10.699999            24.405605
#
#     ImageNet100-R Error  LearningRate          Loss   Network  \
# 90            51.487327           0.1  StandardLoss  resnet18
#
#                                                  Path  Scaling  WeightDecay  \
# 90  /work/dlclarge1/agnihotr-ensemble/scaled_resne...     1.73       0.0002
#
#     kd_T kd_mixture
# 90  None       None

# %%
standard_scaled
# Out:
#       Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  \
# 270  False   False        False      90          10.320002
#
#      ImageNet100-C Error  ImageNet100-R Error  LearningRate          Loss  \
# 270            48.304266            67.149508           0.1  StandardLoss
#
#       Network                                               Path  Scaling  \
# 270  resnet18  /work/dlclarge1/agnihotr-ensemble/scaled_resne...     1.73
#
#      WeightDecay  kd_T kd_mixture
# 270       0.0002  None       None

# %%
pruned_scaled
# Out:
#       Amda  Augmix  Batch Size  DeepAugment  Epochs  ImageNet100 Error  \
# 90    True    True         256         True      30          10.219997
# 90    True    True         256         True      30          10.380000
# 90    True    True         256         True      30          11.540002
# 90    True    True         256         True      30          13.980001
# 90    True    True         256         True      30          28.020000
# 270  False   False         256        False      90           9.740001
# 270  False   False         256        False      90          10.380000
# 270  False   False         256        False      90          10.460001
# 270  False   False         256        False      90          12.199998
# 270  False   False         256        False      90          21.640003
#
#      ImageNet100-C Error  ImageNet100-R Error  LearningRate          Loss  \
# 90             23.260272            50.142267           0.1  StandardLoss
# ...

# %%
amda_pruned_scaled=pruned_scaled.query("Amda")
amda_pruned_scaled = amda_pruned_scaled.combine(amda_scaled).sort
# Out:
#     Amda  Augmix  Batch Size  DeepAugment  Epochs  ImageNet100 Error  \
# 90  True    True         256         True      30          10.219997
# 90  True    True         256         True      30          10.380000
# 90  True    True         256         True      30          11.540002
# 90  True    True         256         True      30          13.980001
# 90  True    True         256         True      30          28.020000
#
#     ImageNet100-C Error  ImageNet100-R Error  LearningRate          Loss  ...  \
# 90            23.260272            50.142267           0.1  StandardLoss  ...
# 90            23.618406            50.129333           0.1  StandardLoss  ...
# 90            25.634938            51.176926           0.1  StandardLoss  ...
# 90            29.572266            53.905845           0.1  StandardLoss  ...
# 90            48.176533            66.800311           0.1  StandardLoss  ...
#
#    Prune Ratio Scaling   SupCon Loss Supcon Amda  Temperature  WeightDecay  \
# ...

# %%
std_pruned_scaled=pruned_scaled.query("not Amda")
std_pruned_scaled
# Out:
#       Amda  Augmix  Batch Size  DeepAugment  Epochs  ImageNet100 Error  \
# 270  False   False         256        False      90           9.740001
# 270  False   False         256        False      90          10.380000
# 270  False   False         256        False      90          10.460001
# 270  False   False         256        False      90          12.199998
# 270  False   False         256        False      90          21.640003
#
#      ImageNet100-C Error  ImageNet100-R Error  LearningRate          Loss  \
# 270            47.260797            66.528711           0.1  StandardLoss
# 270            47.458404            66.554579           0.1  StandardLoss
# 270            48.577332            66.554579           0.1  StandardLoss
# 270            52.069604            67.498708           0.1  StandardLoss
# 270            65.856266            75.006467           0.1  StandardLoss
#
#      ... Prune Ratio Scaling   SupCon Loss Supcon Amda  Temperature  \
# ...

# %%
add_info(amda_scaled)
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90  True    True         True      30          10.699999            24.405605
#
#     ImageNet100-R Error  LearningRate          Loss   Network  \
# 90            51.487327           0.1  StandardLoss  resnet18
#
#                                                  Path  Scaling  WeightDecay  \
# 90  /work/dlclarge1/agnihotr-ensemble/scaled_resne...     1.73       0.0002
#
#     kd_T kd_mixture          MACs  Model Size
# 90  None       None  5.260574e+09    33.42918

# %%
add_info(standard_scaled)
# Out:
#       Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  \
# 270  False   False        False      90          10.320002
#
#      ImageNet100-C Error  ImageNet100-R Error  LearningRate          Loss  \
# 270            48.304266            67.149508           0.1  StandardLoss
#
#       Network                                               Path  Scaling  \
# 270  resnet18  /work/dlclarge1/agnihotr-ensemble/scaled_resne...     1.73
#
#      WeightDecay  kd_T kd_mixture          MACs  Model Size
# 270       0.0002  None       None  5.260574e+09    33.42918

# %%
add_info(pruned_scaled)
# Out:
#       Amda  Augmix  Batch Size  DeepAugment  Epochs  ImageNet100 Error  \
# 90    True    True         256         True      30          10.219997
# 90    True    True         256         True      30          10.380000
# 90    True    True         256         True      30          11.540002
# 90    True    True         256         True      30          13.980001
# 90    True    True         256         True      30          28.020000
# 270  False   False         256        False      90           9.740001
# 270  False   False         256        False      90          10.380000
# 270  False   False         256        False      90          10.460001
# 270  False   False         256        False      90          12.199998
# 270  False   False         256        False      90          21.640003
#
#      ImageNet100-C Error  ImageNet100-R Error  LearningRate          Loss  \
# 90             23.260272            50.142267           0.1  StandardLoss
# ...

# %%
amda_10 = 30.287340
amda_25 = 25.266156
amda_50 = 16.824300
amda_70 = 10.098924
amda_90 = 3.348972
std_10 = 30.287340
std_25 = 25.266156
std_50 = 16.824300
std_70 = 10.098924
std_90 = 3.348972

# %%
amda_pruned_sep=collect(Path("/work/dlclarge1/agnihotr-ensemble/train_emsemble/imagenet100/amda/seperated/performance")).sort_values(by="Path")
amda_pruned_sep["Amda"]=["True", "True", "True", "True", "True"]
amda_pruned_sep["Augmix"]=["True", "True", "True", "True", "True"]
amda_pruned_sep["DeepAugment"]=["True", "True", "True", "True", "True"]
amda_pruned_sep["Model Size"]=[30.287340, 25.266156, 16.824300, 10.098924, 3.348972]
amda_pruned_sep
# Out:
#    Amda Augmix DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 0  True   True        True       0          10.820001            24.555469
# 0  True   True        True       0          11.420000            25.298935
# 0  True   True        True       0          13.120002            28.373873
# 0  True   True        True       0          17.019999            34.610665
# 0  True   True        True       0          35.780001            55.733603
#
#    ImageNet100-R Error  LearningRate          Loss   Network  \
# 0            50.316864           0.1  StandardLoss  resnet18
# 0            51.073462           0.1  StandardLoss  resnet18
# 0            52.373254           0.1  StandardLoss  resnet18
# 0            56.531298           0.1  StandardLoss  resnet18
# 0            72.199950           0.1  StandardLoss  resnet18
#
#                                                 Path  Scaling  WeightDecay  \
# ...

# %%
std_pruned_sep=collect(Path("/work/dlclarge1/agnihotr-ensemble/train_emsemble/imagenet100/standard/seperated/performance")).sort_values(by="Path")
std_pruned_sep["Model Size"]=[30.287340, 25.266156, 16.824300, 10.098924, 3.348972]
std_pruned_sep
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 0  False   False        False       0           9.240001            46.432799
# 0  False   False        False       0           9.640002            47.113597
# 0  False   False        False       0          10.619998            49.423730
# 0  False   False        False       0          12.639999            54.027998
# 0  False   False        False       0          25.959998            70.055467
#
#    ImageNet100-R Error  LearningRate          Loss   Network  \
# 0            64.019659           0.1  StandardLoss  resnet18
# 0            64.317125           0.1  StandardLoss  resnet18
# 0            64.892653           0.1  StandardLoss  resnet18
# 0            66.961977           0.1  StandardLoss  resnet18
# 0            77.463786           0.1  StandardLoss  resnet18
#
#                                                 Path  Scaling  WeightDecay  \
# ...

# %%
hydra_path = [Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hoffmaja-pruneshift/experiments/img100/workshop/subnet_final/tune/"),
              Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mnasnet/hydra_amda/finetune/"),
              Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mobilenet_v2/hydra_amda/finetune/"),
              Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mnasnet/hydra_kd_amda/finetune/"),
              Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mobilenet_v2//hydra_kd_amda/finetune/"),
              Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hoffmaja-pruneshift/shashank_runs/icml_runs_new/amda_resnet/mask_selection/finetuning")]
weight_path = [Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hoffmaja-pruneshift/experiments/img100/workshop/subnet_final/global_weight/"),
               Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mnasnet/layer_weights_amda/"),
               Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hoffmaja-pruneshift/shashank_runs/icml_runs_new/mobilenet_v2/layer_weight_amda/")]
baseline_path = Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hoffmaja-pruneshift/experiments/img100/workshop/baselines")
errors = ["ImageNet100 Error", "ImageNet100-C Error", "ImageNet100-R Error"]

order = {'Global Weight': 2, 'Layer Weight': 2, 'Hydra': 1, 'Hydra with KD': 0} 

hydra_amda_path = Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hoffmaja-pruneshift/shashank_runs/icml_runs_new/amda_resnet/mask_selection/finetuning")

sns.set_context("talk")
sns.set_style("whitegrid")

# %%
df_baseline = collect(baseline_path).query("Scaling == 1")
df_baseline
# Out:
#       Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  \
# 270  False   False        False      90          11.760002
# 90    True    True         True      30          13.160002
# 90    True    True         True      30          12.980002
# 90    True    True         True      30          13.080001
# 270  False   False        False      90          11.739999
# 270  False   False        False      90          11.379999
#
#      ImageNet100-C Error  ImageNet100-R Error  LearningRate          Loss  \
# 270            54.321861            68.901965           0.1  StandardLoss
# 90             30.421329            56.350234           0.1  StandardLoss
# 90             28.012806            53.563115           0.1  StandardLoss
# 90             30.392003            55.988100           0.1  StandardLoss
# 270            51.112539            68.669167           0.1  StandardLoss
# 270            53.167999            69.374031           0.1  StandardLoss
#
# ...

# %%
df_hydra_amda = collect(*hydra_path).sort_values(by="Path")#.query("Teacher.isnull() & `Hydra Amda` & Amda")
df_hydra_amda["Prune Method"] = "Hydra"

# %%
res50={'Amda': [True,False], 'AugMix': [True,True], 'ImageNet100 Error': [6.20,5.50], 'ImageNet100-C Error': [20.60,29.00], 'ImageNet100-R Error': [44.90,52.30], 'Network': ['AMDA ResNet50','AM ResNet50'], 'Model Size':[25.636712,25.636712]} 
res101_32={'Amda': True, 'ImageNet100 Error': 4.70, 'ImageNet100-C Error': 15.00, 'ImageNet100-R Error': 40.30, 'Network': 'ResNeXt101_32x8d', 'Model Size':88.791336}

# %%
mnas=df_baseline.query("Network=='mnasnet1_0' and Amda").copy()
mobile=df_baseline.query("Network=='mobilenet_v2' and Amda").copy()
add_info(mobile)
add_info(mnas)
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90  True    True         True      30          13.080001            30.392003
#
#     ImageNet100-R Error  LearningRate          Loss     Network  \
# 90              55.9881           0.1  StandardLoss  mnasnet1_0
#
#                                                  Path  Scaling  WeightDecay  \
# 90  /work/dlclarge2/agnihotr-shashank-pruneshift/h...        1       0.0002
#
#     kd_T kd_mixture         MACs  Model Size
# 90  None       None  328975332.0    3.230412

# %%
df_hydra_kd_amda = collect(*hydra_path).sort_values(by="Path").query("not Teacher.isnull()")#& `Hydra Loss` != 'StandardLoss'& `Hydra Amda` & Amda").drop_duplicates()
df_hydra_kd_amda["Prune Method"] = "Hydra with KD"
add_info(df_hydra_kd_amda)
ours=df_hydra_kd_amda.iloc[0]

# %%
res18=df_baseline.query("Network=='resnet18' and Amda").copy()
add_info(res18)
# Out:
#     Amda  Augmix  DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90  True    True         True      30          12.980002            28.012806
#
#     ImageNet100-R Error  LearningRate          Loss   Network  \
# 90            53.563115           0.1  StandardLoss  resnet18
#
#                                                  Path  Scaling  WeightDecay  \
# 90  /work/dlclarge2/agnihotr-shashank-pruneshift/h...        1       0.0002
#
#     kd_T kd_mixture          MACs  Model Size
# 90  None       None  1.821716e+09   11.227812

# %%
res50=pd.DataFrame(data=res50)

# %%
ours=collect(Path("/work/dlclarge2/agnihotr-shashank-pruneshift/hyperparameter_analysis/goodconfig/finetune")).query("Network=='resnet18' & `Prune Ratio`==10 & `Hydra Loss`=='KnowledgeDistill'")

# %%
add_info(ours)
# Out:
#     Amda  Augmix  Batch Size  DeepAugment  Epochs  Hydra Amda  \
# 90  True    True         256         True      30        True
#
#           Hydra Loss  ImageNet100 Error  ImageNet100-C Error  \
# 90  KnowledgeDistill          10.799998            27.344263
#
#     ImageNet100-R Error  ...  Scaling       SupCon Loss Supcon Amda  \
# 90            52.004656  ...        1  KnowledgeDistill        True
#
#           Teacher  Temperature  WeightDecay kd_T  kd_mixture         MACs  \
# 90  AMDA ResNet50         None      0.00009    2         0.7  286118437.0
#
#    Model Size
# 90   1.122791
#
# [1 rows x 25 columns]

# %%
ours=ours.replace("resnet18","90%pr+KD ResNet18")

# %%
combine=res18.append(ours)
combine=combine.append(mobile)
combine=combine.append(mnas)
combine=combine.append(res50)

# %%
combine
# Out:
#      Amda Augmix DeepAugment  Epochs  ImageNet100 Error  ImageNet100-C Error  \
# 90   True   True        True    30.0          12.980002            28.012806
# 90   True   True        True    30.0          10.799998            27.344263
# 90   True   True        True    30.0          13.160002            30.421329
# 90   True   True        True    30.0          13.080001            30.392003
# 0    True    NaN         NaN     NaN           6.200000            20.600000
# 1   False    NaN         NaN     NaN           5.500000            29.000000
#
#     ImageNet100-R Error  LearningRate              Loss            Network  \
# 90            53.563115         0.100      StandardLoss           resnet18
# 90            52.004656         0.058  KnowledgeDistill  90%pr+KD ResNet18
# 90            56.350234         0.100      StandardLoss       mobilenet_v2
# 90            55.988100         0.100      StandardLoss         mnasnet1_0
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(17.5, 5))

for ax, error in zip(axes.flatten(), ["ImageNet100 Error", "ImageNet100-C Error", "ImageNet100-R Error"]):
    #sns.lineplot(data=df_comb_special, x="Model Size", y=error, style="Network", hue="Network", marker="o", ax=ax)
    sns.scatterplot(data=combine, x="Model Size", y=error, ax=ax, style="Network", hue="Network", s=200)
    #sns.regplot(data=combine, x="Model Size", y=error, ax=ax)#, style="Network")
    # ax.legend(loc="lower center", borderaxespad=-6., ncol=3, )
    ax.set_xlabel("Num. of Parameters (millions)")
    ax.set_ylabel(error + " (%)")
    #ax.set_xlim(0, 3.5)
    ax.set_title(error.split(" ")[0])
    # ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    if error != "ImageNet10-R Error":
        ax.legend('', frameon=False)
    pts = []
    
    #mid = (pts[0] + pts[1]) / 2 + np.array([-1, 10])

    #for coords in pts:
        #ax.annotate('Unpruned Models', xy=coords, xytext=mid, color="grey",
                    #arrowprops=dict(facecolor='grey', shrink=0.05, alpha=0.7),
                    #)
    handles, labels = ax.get_legend_handles_labels()
    #fig.legend(handles, labels, bbox_to_anchor=(1.04,0.5), loc="center left", ncol=1, title="Models")
    fig.legend(handles, labels, loc=2, bbox_to_anchor=(0.28, 1.2), borderaxespad=0., ncol=3, title="Models")#
plt.tight_layout()
plt.savefig(f"figures/final_comparison.pdf", bbox_inches="tight")

# %%
# df_comb_special["MACs"] /= 1e6
for error in ["ImageNet100 Error", "ImageNet100-C Error", "ImageNet100-R Error"]:
    fig, ax = plt.subplots(figsize=(11, 5))
    sns.lineplot(data=df_comb_special, x="MACs", y=error, style="Network", hue="Network", marker="o", ax=ax)
    # ax.legend(loc="lower center", borderaxespad=-6., ncol=3, )
    ax.set_xlabel("MACs (millions)")
    ax.set_ylabel(error + " (%)")
    ax.set_xlim(0, 750)

    pts = []
    for network in ["mnasnet1_0", "mobilenet_v2"]:
        y, x = df_baseline.query(f"Amda & Network == '{network}'")[[error, "MACs"]].to_numpy()[0]
        pts.append(np.array([x, y]))
        # ax.scatter(x, y, zorder=19)
    
    continue
    mid = (pts[0] + pts[1]) / 2 + np.array([-0.3, 10])

    for coords in pts:
        ax.annotate('Unpruned Models', xy=coords, xytext=mid, color="grey",
                    arrowprops=dict(facecolor='grey', shrink=0.05, alpha=0.7),
                    )
    plt.tight_layout()
    plt.savefig(f"figures/hydra_model_size_tradeoff_{error}_macs.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-fdb2c383d2e1> in <module>
#       2 for error in ["ImageNet100 Error", "ImageNet100-C Error", "ImageNet100-R Error"]:
#       3     fig, ax = plt.subplots(figsize=(11, 5))
# ----> 4     sns.lineplot(data=df_comb_special, x="MACs", y=error, style="Network", hue="Network", marker="o", ax=ax)
#       5     # ax.legend(loc="lower center", borderaxespad=-6., ncol=3, )
#       6     ax.set_xlabel("MACs (millions)")
#
# NameError: name 'df_comb_special' is not defined

# %%
for network in df_baseline["Network"].unique():
    fig, axes = plt.subplots(1, 3, figsize=(15.5, 5.5))
    for ax, error in zip(axes.flatten(), ["ImageNet100 Error", "ImageNet100-C Error", "ImageNet100-R Error"]):
        sns.lineplot(data=df.query(f"Network == '{network}'"), x="Prune Ratio", y=f"{error}", hue="Prune Method", ax=ax, marker="s")
        if not error == "ImageNet100 Error":
            ax.legend('', frameon=False)
        ax.set_ylabel(f"{error} (%)")
        ax.set_xlabel("Compression Ratio")

        caption = error.split(" ")[0]
        ax.set_title(f"{caption}")
    
        y = df_baseline.query(f"Amda & Network == '{network}'")[error].item() # - df_baseline.query("not Amda")[error].item()
        ax.axhline(y, color="grey", ls="dashed")
        # ax.text(30, y, 'Unpruned Model', fontsize=11, va='center', ha='center', backgroundcolor='w', color="grey")

    plt.tight_layout()
    plt.savefig(f"figures/pruning_supp_hydra_weight_{network}.pdf")

# %%
df2 = df.query("Network == 'resnet18'") # & `Prune Method` != 'Hydra with KD'")

sns.set_context("talk")
sns.set_style("whitegrid")
fig, axes = plt.subplots(1, 3, figsize=(11.7, 5.5))

for ax, error in zip(axes.flatten(), ["ImageNet100 Error", "ImageNet100-C Error", "ImageNet100-R Error"]):
    sns.lineplot(data=df2, x="Prune Ratio", y=f"{error}", hue="Prune Method", ax=ax, marker="s")

    ax.set_ylabel(f"{error} (%)")
    ax.set_xlabel("Compression Ratio")

    caption = error.split(" ")[0]
    ax.set_title(f"{caption}")

    # handles, labels = ax.get_legend_handles_labels()
    if error != "ImageNet100 Error":
        ax.legend('', frameon=False)
    y = df_baseline.query("Amda & Network == 'resnet18'")[error].item() # - df_baseline.query("not Amda")[error].item()
    ax.axhline(y, color="grey", ls="dashed")
    # ax.text(1.2, y, 'Unpruned without AMDA', fontsize=11, va='center', ha='center', backgroundcolor='w', color="grey")

# fig.legend(handles, labels, loc="lower center", borderaxespad=0., ncol=5, bbox_to_anchor=(0,-0.05,1,0.2)) #, title="Prune Methods:")
plt.tight_layout()
plt.savefig("figures/pruning_main_hydra_plot.pdf")

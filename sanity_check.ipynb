# %%
from pruneshift.networks import create_network
from pruneshift.prune_info import PruneInfo

# %%
net = create_network("cifar100_resnet20", ckpt_path="/misc/lmbraid19/hoffmaja/experiments/2021-02-12/11-39-01/checkpoint/last.ckpt")

# %%
PruneInfo(net).summary()
# Out:
#             module   param      comp    amount   size           shape  target  protected
# 0            conv1  weight  4.000000  0.750000    432   (16, 3, 3, 3)    True      False
# 1   layer1.0.conv1  weight  4.000000  0.750000   2304  (16, 16, 3, 3)    True      False
# 2   layer1.0.conv2  weight  4.000000  0.750000   2304  (16, 16, 3, 3)    True      False
# 3   layer1.1.conv1  weight  4.000000  0.750000   2304  (16, 16, 3, 3)    True      False
# 4   layer1.1.conv2  weight  4.000000  0.750000   2304  (16, 16, 3, 3)    True      False
# 5   layer1.2.conv1  weight  4.000000  0.750000   2304  (16, 16, 3, 3)    True      False
# 6   layer1.2.conv2  weight  4.000000  0.750000   2304  (16, 16, 3, 3)    True      False
# 7   layer2.0.conv1  weight  4.571429  0.781250   4608  (32, 16, 3, 3)    True      False
# 8   layer2.0.conv2  weight  4.571429  0.781250   9216  (32, 32, 3, 3)    True      False
# ...

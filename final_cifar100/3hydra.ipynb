# %%
from utils import collect, add_info
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from math import pi
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import numpy as np


errors = ["Cifar100 Error", "Cifar100-C Error"]

order = {'Global Weight': 2, 'Layer Weight': 2, 'Hydra': 1, 'Hydra with KD': 0} 

sns.set_context("talk")
sns.set_style("whitegrid")

# %%
df_gw_kd=collect(Path("/work/dlclarge2/agnihotr-shashank-pruneshift/final_cifar100/global_weight/with_kd")).sort_values(by=["Prune Ratio"])
df_gw_kd
# Out:
#       Amda  Augmix  Batch Size  Cifar100 Error  Cifar100-C Error  DeepAugment  \
# 300  False    True         128       25.340003         36.435568        False
# 300  False    True         128       25.559998         37.929785        False
# 300  False    True         128       28.460002         41.499788        False
# 300  False    True         128       28.570002         41.402739        False
# 300  False    True         128       33.389997         47.621161        False
#
#      Epochs  LearningRate              Loss   Network  ...   Prune Method  \
# 300     100           0.1  KnowledgeDistill  resnet18  ...  Global Weight
# 300     100           0.1  KnowledgeDistill  resnet18  ...  Global Weight
# 300     100           0.1  KnowledgeDistill  resnet18  ...  Global Weight
# 300     100           0.1  KnowledgeDistill  resnet18  ...  Global Weight
# 300     100           0.1  KnowledgeDistill  resnet18  ...  Global Weight
#
# ...

# %%
df_gw=collect(Path("/work/dlclarge2/agnihotr-shashank-pruneshift/final_cifar100/global_weight/no_kd")).sort_values(by=["Prune Ratio"])
df_gw
# Out:
#       Amda  Augmix  Batch Size  Cifar100 Error  Cifar100-C Error  DeepAugment  \
# 300  False    True         128       26.880002         37.236631        False
# 300  False    True         128       26.789999         37.860525        False
# 300  False    True         128       28.810000         40.861481        False
# 300  False    True         128       34.399998         47.259891        False
#
#      Epochs  LearningRate          Loss   Network  ... Prune Amount  \
# 300     100           0.1  StandardLoss  resnet18  ...       0.9000
# 300     100           0.1  StandardLoss  resnet18  ...       0.9500
# 300     100           0.1  StandardLoss  resnet18  ...       0.9750
# 300     100           0.1  StandardLoss  resnet18  ...       0.9875
#
#       Prune Method Prune Ratio  Scaling   SupCon Loss Supcon Amda  \
# 300  Global Weight          10        1  StandardLoss       False
# 300  Global Weight          20        1  StandardLoss       False
# ...

# %%
df_gw=collect(Path("/work/dlclarge2/agnihotr-shashank-pruneshift/final_cifar100/global_weight/no_kd_redo")).sort_values(by=["Prune Ratio"])
df_gw
# Out:
#       Amda  Augmix  Batch Size  Cifar100 Error  Cifar100-C Error  DeepAugment  \
# 300  False    True         128       27.090001         37.053156        False
# 300  False    True         128       27.179998         38.006002        False
# 300  False    True         128       28.810000         40.861481        False
# 300  False    True         128       34.560001         47.165477        False
#
#      Epochs  LearningRate          Loss   Network  ... Prune Amount  \
# 300     100           0.1  StandardLoss  resnet18  ...       0.9000
# 300     100           0.1  StandardLoss  resnet18  ...       0.9500
# 300     100           0.1  StandardLoss  resnet18  ...       0.9750
# 300     100           0.1  StandardLoss  resnet18  ...       0.9875
#
#       Prune Method Prune Ratio  Scaling   SupCon Loss Supcon Amda  \
# 300  Global Weight          10        1  StandardLoss       False
# 300  Global Weight          20        1  StandardLoss       False
# ...

# %%
df_hydra_kd=collect(Path("/work/dlclarge2/agnihotr-shashank-pruneshift/final_cifar100/combine_hydra_distill/finetuned")).sort_values(by=["Prune Ratio"])
df_hydra_kd=df_hydra_kd.sort_values(by=["Cifar100 Error"]).drop_duplicates(["Prune Ratio"])

# %%
df_hydra=collect(Path("/work/dlclarge2/agnihotr-shashank-pruneshift/final_cifar100/hydra/finetune")).sort_values(by=["Prune Ratio"])

# %%
add_info(df_gw)
# Out:
#       Amda  Augmix  Batch Size  Cifar100 Error  Cifar100-C Error  DeepAugment  \
# 300  False    True         128       27.090001         37.053156        False
# 300  False    True         128       27.179998         38.006002        False
# 300  False    True         128       28.810000         40.861481        False
# 300  False    True         128       34.560001         47.165477        False
#
#      Epochs  LearningRate          Loss   Network  ... Prune Ratio  Scaling  \
# 300     100           0.1  StandardLoss  resnet18  ...          10        1
# 300     100           0.1  StandardLoss  resnet18  ...          20        1
# 300     100           0.1  StandardLoss  resnet18  ...          40        1
# 300     100           0.1  StandardLoss  resnet18  ...          80        1
#
#       SupCon Loss  Supcon Amda  Temperature WeightDecay  kd_T kd_mixture  \
# 300  StandardLoss        False         None      0.0002  None       None
# ...

# %%
add_info(df_gw_kd)
# Out:
#       Amda  Augmix  Batch Size  Cifar100 Error  Cifar100-C Error  DeepAugment  \
# 300  False    True         128       25.340003         36.435568        False
# 300  False    True         128       25.559998         37.929785        False
# 300  False    True         128       28.460002         41.499788        False
# 300  False    True         128       28.570002         41.402739        False
# 300  False    True         128       33.389997         47.621161        False
#
#      Epochs  LearningRate              Loss   Network  ... Scaling  \
# 300     100           0.1  KnowledgeDistill  resnet18  ...       1
# 300     100           0.1  KnowledgeDistill  resnet18  ...       1
# 300     100           0.1  KnowledgeDistill  resnet18  ...       1
# 300     100           0.1  KnowledgeDistill  resnet18  ...       1
# 300     100           0.1  KnowledgeDistill  resnet18  ...       1
#
#       SupCon Loss Supcon Amda      Teacher  Temperature WeightDecay  kd_T  \
# ...

# %%
add_info(df_hydra)
# Out:
#       Amda  Augmix  Batch Size  Cifar100 Error  Cifar100-C Error  DeepAugment  \
# 300  False    True         128       26.718142         37.132108        False
# 300  False    True         128       27.014999         37.588209        False
# 300  False    True         128       27.960002         40.477473        False
# 300  False    True         128       34.214519         46.775258        False
#
#      Epochs  Hydra Amda    Hydra Loss  LearningRate  ... Prune Ratio Scaling  \
# 300     100       False  StandardLoss           0.1  ...          10       1
# 300     100       False  StandardLoss           0.1  ...          20       1
# 300     100       False  StandardLoss           0.1  ...          40       1
# 300     100       False  StandardLoss           0.1  ...          80       1
#
#       SupCon Loss  Supcon Amda  Temperature WeightDecay  kd_T kd_mixture  \
# 300  StandardLoss        False         None      0.0002  None       None
# ...

# %%
add_info(df_hydra_kd)
# Out:
#       Amda  Augmix  Batch Size  Cifar100 Error  Cifar100-C Error  DeepAugment  \
# 300  False    True         128       25.129998         36.074632        False
# 300  False    True         128       25.239998         36.927688        False
# 300  False    True         128       27.270001         38.565266        False
# 300  False    True         128       33.310002         46.285790        False
#
#      Epochs  Hydra Amda        Hydra Loss  LearningRate  ...  \
# 300     100       False  KnowledgeDistill           0.1  ...
# 300     100       False  KnowledgeDistill           0.1  ...
# 300     100       False  KnowledgeDistill           0.1  ...
# 300     100       False  KnowledgeDistill           0.1  ...
#
#           SupCon Loss Supcon Amda      Teacher  Temperature  WeightDecay kd_T  \
# 300  KnowledgeDistill       False  AM ResNet50         None       0.0002  4.0
# 300  KnowledgeDistill       False  AM ResNet50         None       0.0002  4.0
# ...

# %%
df_std_baseline=collect(Path("/work/dlclarge2/agnihotr-shashank-pruneshift/final_cifar100/baseline/standard"))
add_info(df_std_baseline)
df_aug_baseline=collect(Path("/work/dlclarge2/agnihotr-shashank-pruneshift/final_cifar100/baseline/augmix"))
add_info(df_aug_baseline)
# Out:
#       Amda  Augmix  Cifar100 Error  Cifar100-C Error  DeepAugment  Epochs  \
# 300  False    True       26.990002         36.449265        False     100
#
#      LearningRate          Loss   Network  \
# 300           0.1  StandardLoss  resnet18
#
#                                                   Path  Scaling  WeightDecay  \
# 300  /work/dlclarge2/agnihotr-shashank-pruneshift/f...        1       0.0002
#
#      kd_T kd_mixture          MACs  Model Size
# 300  None       None  2.730663e+10   11.220132

# %%
prune_method=["Hydra","Hydra","Hydra","Hydra"]
prune_method_kd=["Hydra with KD","Hydra with KD","Hydra with KD","Hydra with KD"]
df_hydra["Prune Method"]=prune_method
df_hydra_kd["Prune Method"]=prune_method_kd

# %%
df_hydra_plot=df_hydra.copy()
df_gw_plot=df_gw.copy()
df_hydra_kd_plot=df_hydra_kd.copy()
df_gw_kd_plot=df_gw_kd.copy()

# %%
df_hydra_plot["Cifar100 Error"]=-(df_hydra_plot["Cifar100 Error"]-df_aug_baseline["Cifar100 Error"])
df_hydra_kd_plot["Cifar100 Error"]=-(df_hydra_kd_plot["Cifar100 Error"]-df_aug_baseline["Cifar100 Error"])
df_gw_plot["Cifar100 Error"]=-(df_gw_plot["Cifar100 Error"]-df_aug_baseline["Cifar100 Error"])
df_gw_kd_plot["Cifar100 Error"]=-(df_gw_kd_plot["Cifar100 Error"]-df_aug_baseline["Cifar100 Error"])
df_hydra_plot["Cifar100-C Error"]=-(df_hydra_plot["Cifar100-C Error"]-df_aug_baseline["Cifar100-C Error"])
df_hydra_kd_plot["Cifar100-C Error"]=-(df_hydra_kd_plot["Cifar100-C Error"]-df_aug_baseline["Cifar100-C Error"])
df_gw_plot["Cifar100-C Error"]=-(df_gw_plot["Cifar100-C Error"]-df_aug_baseline["Cifar100-C Error"])
df_gw_kd_plot["Cifar100-C Error"]=-(df_gw_kd_plot["Cifar100-C Error"]-df_aug_baseline["Cifar100-C Error"])

# %%
combine=df_hydra_plot.append(df_gw_plot)

# %%
combine=pd.read_csv('pruning_cifar_aug.csv')

# %%
sns.set_style("whitegrid")
ERROR_LABELS = {"Cifar100 Error": "Cifar100", "Cifar100-C Error": "Cifar100-C"}

for network in combine["Network"].unique():
    fig, axes = plt.subplots(1, 2, figsize=(15.5, 5.5))
    #df_part = df_prune.query(f"Network == '{network}' & not Amda")

    for (error, label), ax in zip(ERROR_LABELS.items(), axes.flatten()):
        sns.barplot(data=combine, x="Prune Ratio", y=error , hue="Prune Method", ax=ax)
        plt.tight_layout()

        handles, labels = ax.get_legend_handles_labels()
        ax.legend('', frameon=False)
        ax.set_title(label)
        ax.set_ylabel(error + " (%)" )
        ax.set_xlabel("Compression Ratio")

    fig.tight_layout(pad=2.5)
    fig.legend(handles, labels, loc="lower center", borderaxespad=0., ncol=5)

    plt.savefig(f"figures/cifar_hydra_vs_gw.pdf")

# %%
combine=df_hydra_kd.append(df_hydra)
combine=combine.append(df_gw)

# %%
combine
# Out:
#       Amda  Augmix  Batch Size  Cifar100 Error  Cifar100-C Error  DeepAugment  \
# 300  False    True         128       25.129998         36.074632        False
# 300  False    True         128       25.239998         36.927688        False
# 300  False    True         128       27.270001         38.565266        False
# 300  False    True         128       33.310002         46.285790        False
# 300  False    True         128       26.718142         37.132108        False
# 300  False    True         128       27.014999         37.588209        False
# 300  False    True         128       27.960002         40.477473        False
# 300  False    True         128       34.214519         46.775258        False
# 300  False    True         128       27.090001         37.053156        False
# 300  False    True         128       27.179998         38.006002        False
# 300  False    True         128       28.810000         40.861481        False
# ...

# %%
df_aug_baseline=collect(Path("/work/dlclarge2/agnihotr-shashank-pruneshift/final_cifar100/baseline/augmix"))

# %%
combine=pd.read_csv("hydra_kd.csv")

# %%
sns.set_style("whitegrid")
ERROR_LABELS = {"Cifar100 Error": "Cifar100", "Cifar100-C Error": "Cifar100-C"}

for network in combine["Network"].unique():
    fig, axes = plt.subplots(1, 2, figsize=(15.5, 5.5))
    #df_part = df_prune.query(f"Network == '{network}' & not Amda")

    for (error, label), ax in zip(ERROR_LABELS.items(), axes.flatten()):
        sns.lineplot(data=combine, x="Prune Ratio", y=error , hue="Prune Method", ax=ax, marker='s')
        plt.tight_layout()
        ax.axhline(df_aug_baseline.query("Network == 'resnet18'")[error].item(), color="grey", ls="dashed")
        handles, labels = ax.get_legend_handles_labels()
        ax.legend('', frameon=False)
        ax.set_title(label)
        ax.set_ylabel(error + " (%)" )
        ax.set_xlabel("Compression Ratio")

    fig.tight_layout(pad=2.5)
    #fig.legend(handles, labels, loc="lower center", borderaxespad=0., ncol=2)
    fig.legend(handles, labels, bbox_to_anchor=(0.36, 1.1), loc=2, borderaxespad=0., ncol=3, title="Prune Method")#
    plt.savefig(f"figures/cifar_hydra_kd_vs_gw.pdf", bbox_inches="tight")

# %%
combine.to_csv("hydra_kd.csv")

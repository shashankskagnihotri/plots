# %%
import pandas as pd
import seaborn as sns

# %%
df_r = pd.read_csv("https://raw.githubusercontent.com/rwightman/pytorch-image-models/master/results/results-imagenet-r.csv")

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rwightman/pytorch-image-models/master/results/results-imagenet-r-clean.csv")

# %%
df["rend top1"] = df_r["top1"]

# %%
sns.relplot(data=df, x="top1", y="rend top1")

# %%
sns.relplot(data=df_r, x="top1", y="param_count")

# %%
sns.relplot(data=df_v, x="top1", y="param_count")

# %%
import torch


def convert_ckpt(path):
    state = torch.load(path)

state = torch.load("/misc/lmbraid19/hoffmaja/models/augmix/cifar100_resnet18.0")

state
# Out:
# {'epoch': 142,
#  'global_step': 55522,
#  'pytorch-lightning_version': '1.0.7',
#  'state_dict': OrderedDict([('network.conv1.weight',
#                tensor([[[[ 1.6745e-02,  2.7582e-02,  2.0421e-03],
#                          [-4.0251e-02,  1.8726e-01, -2.5611e-02],
#                          [ 2.8650e-02,  3.0324e-02, -1.2899e-01]],
#
#                         [[-3.3821e-01, -1.5871e-01,  7.2578e-02],
#                          [-3.0302e-01,  2.9038e-01,  2.1501e-01],
#                          [ 3.5478e-02,  3.0447e-01, -1.3320e-01]],
#
#                         [[-3.9289e-01, -2.2371e-01,  1.9205e-02],
#                          [-3.8354e-01,  2.9219e-01,  2.9641e-01],
#                          [ 3.4913e-03,  3.7828e-01, -5.5580e-02]]],
#
#
#                        [[[-1.3218e-06, -9.1209e-08, -1.1444e-06],
#                          [-4.1171e-08, -1.2832e-06,  8.5608e-07],
#                          [ 8.2316e-08,  8.4858e-07, -2.2545e-07]],
#
# ...

# %%
import pandas as pd

# %%
pd.read_csv("/work/dlclarge2/hoffmaja-pruneshift/experiments/img100/pruning/prune_std/0/metrics.csv")
# Out:
#      lr-SGD   step  val_acc  val_loss  epoch  train_loss  train_acc
# 0    0.0200      0      NaN       NaN    NaN         NaN        NaN
# 1       NaN    506   0.8250  0.676973    0.0         NaN        NaN
# 2       NaN    506      NaN       NaN    0.0    0.652714   0.822228
# 3    0.0400    507      NaN       NaN    NaN         NaN        NaN
# 4       NaN   1013   0.7730  0.869890    1.0         NaN        NaN
# ..      ...    ...      ...       ...    ...         ...        ...
# 265     NaN  45122   0.8896  0.426131   88.0         NaN        NaN
# 266     NaN  45122      NaN       NaN   88.0    0.340830   0.910272
# 267  0.0001  45123      NaN       NaN    NaN         NaN        NaN
# 268     NaN  45629   0.8896  0.426009   89.0         NaN        NaN
# 269     NaN  45629      NaN       NaN   89.0    0.343250   0.910015
#
# [270 rows x 7 columns]
